# %% [markdown]
# Exploratory Data Analysis (EDA)

# %% [markdown]
# The aim is to extract descriptive statistics, identify trends, and uncover insights that will guide further analysis.
#  * Descriptive Statistics:
# - Obtain basic statistics for textual lengths (like headline length).
# - Count the number of articles per publisher to identify which publishers are most active.
# - Analyze publication dates to see trends over time, such as increased news frequency on particular days or during specific events.

# %% [markdown]
# 1. importing the required libraries for data manipulation and visualization:
#     - pandas for data handling.
#     - matplotlib.pyplot and seaborn for data visualization.

# %%
import os
import sys

project_root = os.path.abspath(os.path.join(os.getcwd(), os.pardir))  # Go up one level
sys.path.insert(0, project_root)  # Add to Python path
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
# Now import will work
# Corrected code snippet with class instantiation
from scripts.financial_analysis import FinancialAnalysis

# Initialize the FinancialAnalysis class

data_analysis = FinancialAnalysis()  # Proper class instantiation

# Load the dataset
data_analysis.load_data()

# Display the first few rows of the dataset (if implemented in FinancialAnalysis)
if data_analysis.df is not None:
    print(data_analysis.df.head())  # Avoid issues if df is None
# Display the first few rows of the dataset
data_analysis.df.head()
#print(f"Current directory: {os.getcwd()}")
#print(f"Project root: {project_root}")
# print(f"Python path: {sys.path}")

# %% [markdown]
# **Data Loading and Initial Analysis**
# - Exploratory analysis to understand the data structure and content.

# %%
data_analysis.explore_data()

# %% [markdown]
# **Data Cleaning and Preprocessing**

# %%
data_analysis.clean_data()
data_analysis.exploratory_analysis()
# Out:
# === Exploratory Analysis ===
#
# Dataset Shape: (1395973, 10)
# Date Range: 2009-02-14 00:00:00-04:00 to 2020-06-11 17:12:35-04:00
#
# Top 10 Most Covered Stocks:
# stock
# MRK     3300
# MS      3149
# MU      3138
# NVDA    3137
# NFLX    3028
# EBAY    3012
# M       2998
# VZ      2962
# GILD    2951
# QCOM    2933
# Name: count, dtype: int64
#
# Articles by Hour of Day:
# hour
# 0     1340058
# 1          14
# 2          57
# 3          93
# 4        1469
# 5        1829
# 6        2475
# 7        5032
# 8        5526
# 9        5965
# 10       7668
# 11       5701
# 12       5732
# 13       2710
# 14       2075
# 15       1612
# 16       3939
# 17       2799
# 18        704
# 19        227
# 20        131
# 21         82
# 22         48
# 23         27
# Name: count, dtype: int64
#
# Headline Length Summary:
# count    1.395973e+06
# mean     7.326273e+01
# std      4.081928e+01
# min      3.000000e+00
# 25%      4.700000e+01
# 50%      6.400000e+01
# 75%      8.700000e+01
# ...

# %% [markdown]
# **📊 Initial Data Analysis Summary:**
# 1. 📈 Dataset Scale:
#
#    - Large dataset with 1.4M records
#    - Clean data with no missing values
#    - Minimal duplicates (<0.1%)
# **2. 📰 Content Analysis:**
#
#  - 845K unique headlines
#   - Most common headlines are analyst ratings (upgrades/downgrades)
#   - 883K unique URLs with some repeated content

# %% [markdown]
# * Descriptive Statistics:
#   * headline length
#   * Count the number of articles per publisher
#   * Analyze the publication dates

# %%
data_analysis.descriptive_statistics()
# Out:
# Headline Length Statistics:
# Average length: 73.3 characters
# Median length: 64.0 characters
# Most common length: 47 characters
#
# Publication Patterns:
# Most active day: Thursday (300097 articles)
# Least active day: Saturday (7720 articles)
#
# Publisher Diversity:
# Total number of unique publishers: 1031
# Top publisher: Paul Quintaro (227495 articles)

# %% [markdown]
# **Key Insights from Descriptive Statistics Analysis:**
# 1. 📏 Headline Length Analysis:
#   - Distribution shows most headlines between 50-100 characters, with peak at 50-60 chars
#   - Strong right-skewed distribution visible in histogram
#   - Clear peak frequency in 50-60 character range
#   - Long tail extends past 200 characters showing outliers
#  2. ⏰ Publisher Analysis:
#    - Benzinga Insights and other top publishers dominate volume
#    - Sharp dropoff in article counts after top 5-6 publishers
#    - Very long tail of smaller publishers with minimal articles
# 3. 📅 Day of Week Distribution:
#     - Strong weekday concentration of articles
#     - Tuesday through Thursday show highest activity levels
#     - Saturday/Sunday have minimal articles (<5% of weekday volume)
#     - Aligns with stock market trading sched.
# 4. 📈 Monthly Article Trends:
#   * Recent periods show substantial volume increases
#   * Early timeframe had consistent lower baseline
#   * Clear exponential growth trend in later periods
#   * Notable month-over-month fluctuations throughout
# e

# %% [markdown]
# ## Text / Sentiment Analysis
#    - Classify headlines: positive/negative/neutral
#    - Measure market sentiment trends

# %%
# Perform sentiment analysis
print("=== Sentiment Analysis ===")
data_analysis.analyze_sentiment()
# Out:
# === Sentiment Analysis ===
#
# Performing Sentiment Analysis...
#
# Sentiment Distribution:
# Neutral: 73.8%
# Positive: 19.2%
# Negative: 6.8%

# %% [markdown]
# **Key Insights from Sentiment Analysis :**
# 1. 📈 Distribution Overview:
#
#    - Neutral sentiment dominates with ~1M headlines
#    - Positive sentiment shows ~250K headlines
#    - Negative sentiment lowest at ~100K headlines
#    - Clear 70-20-10 split between neutral/positive/negative
# 2. 🔄 Pattern Analysis:
#
#    - Strong tendency toward neutral reporting
#    - Positive headlines significantly outnumber negative
#    - Extreme sentiments (very positive/negative) are rare
#    - Distribution aligns with professional financial journalism
# 3. 💡Key Takeaways:
#
#    - Financial news maintains objective tone
#    - Slight positive bias in overall coverage
#    - Balanced reporting with minimal sensationalism
#    - Sentiment distribution suggests credible news sources
# 4. 📈 Temporal Trends:
#
#    - Average sentiment score fluctuates between 0.02-0.06 in recent years
#    - Notable spike in early 2010 reaching ~0.15 sentiment score
#    - Overall trend shows stabilization around 0.04-0.05 range
#    - Monthly variations indicate market sentiment cycles

# %% [markdown]
# **Topic & Phrase Analysis**
# - Extract key topics using NLP
# - Track important events (FDA approvals, mergers, etc.)
# - Monitor financial terms frequency

# %%
# Perform topic modeling
print("\n=== Topic Modeling ===")
data_analysis.extract_topics()
# Out:
# === Topic Modeling ===
#
# Performing Topic Modeling...
# [[0.1        0.1        0.1        0.1        0.59999999]
#  [0.30000016 0.05       0.29999987 0.29999997 0.05      ]
#  [0.30000016 0.05       0.29999987 0.29999997 0.05      ]
#  ...
#  [0.04       0.0401019  0.23999947 0.24000037 0.43989826]
#  [0.39999964 0.06666667 0.40000036 0.06666667 0.06666667]
#  [0.54999961 0.05       0.30000038 0.05       0.05      ]]

# %% [markdown]
# **📊 Key Insights from Topic Modeling:**
# 1. 📈 Topic 1 - Market Performance:
#
#   - Focused on stock price and market movements
#   - Key terms: stock, market, price, week, company
#   - High frequency of stock price tracking terms
# 2. 💼 Topic 2 - Financial Reports:
#
#    - Earnings and financial statement coverage
#    - Terms: report, earnings, quarter, shares, growth
#    - Strong emphasis on periodic financial updates
# 3. 🔄 Topic 3 - Market Analysis:
#
#    - Market trends and movements
#    - Features: market, trading, day, buy, analyst
#    - Focus on daily market activity and analysis
# 4. 📱 Topic 4 - Corporate Updates:
#
#     - Business developments and updates
#     - Terms: stocks, shares, price, deal, business
#     - Coverage of corporate activities and deals
# 5. 💰 Topic 5 - Company Performance:
#
#     - Performance metrics and indicators
#     - Terms: sales, revenue, growth, company, earnings
#     - Emphasis on financial performance metrics

# %% [markdown]
# **🔍 Summarized Observations:**
#
# - Topics closely aligned with visualized word frequencies
# - Clear distinction between daily market news and company fundamentals
# - Balanced coverage across price movements, earnings, and corporate actions

# %%
# Analyze key financial phrases
print("\n=== Key Phrase Analysis ===")
data_analysis.analyze_key_phrases()
# Out:
# === Key Phrase Analysis ===
#
# Analyzing Key Financial Phrases...
#
# Common Financial Phrases Frequency:
# IPO: 0.0 occurrences (0.0%)
# FDA approval: 0.0 occurrences (0.0%)
# analyst rating: 57.0 occurrences (0.0%)
# stock split: 747.0 occurrences (0.1%)
# merger: 5591.0 occurrences (0.4%)
# acquisition: 8847.0 occurrences (0.6%)
# guidance: 15595.0 occurrences (1.1%)
# dividend: 21434.0 occurrences (1.5%)
# price target: 47616.0 occurrences (3.4%)
# upgrade: 61738.0 occurrences (4.4%)
# downgrade: 66678.0 occurrences (4.8%)
# earnings: 86192.0 occurrences (6.2%)

# %% [markdown]
# 📊 **Key Insights from Financial Phrase Analysis:**
# 1. 🎯 Earnings Dominance:
#
#   - Most frequent phrase by far (~8000 occurrences)
#   - Indicates heavy focus on financial performance reporting
#   - Suggests market's strong emphasis on company results
# 2. 📈 Downgrades & Upgrades:
#
#   - Second and third most common themes (~6000 occurrences each)
#   - Shows importance of analyst rating changes
#   - Regular coverage of changing market sentiment
# 3. 📊 Price Targets:
#
#   - Fourth most frequent (~5000 occurrences)
#   - Reflects significant analyst price predictions
#   - Key driver of stock price movements
# 4. 💼 Dividends & Guidance:
#
#   - Moderate frequency (~2000 occurrences)
#   - Regular but less frequent coverage
#   - Important for income-focused investors
# 5. 📋 Corporate Events:
#
#   - Mergers, acquisitions, IPOs less common
#   - Stock splits and FDA approvals least frequent
#   - Major events that drive significant market reactions
# 6. 🔍 Overall Implications:
#
#   - News heavily focused on earnings and analyst opinions
#   - Rating changes generate substantial coverage
#   - Price targets remain key focus for market guidance
#   - Corporate actions get attention but occur less frequently

# %% [markdown]
# 📅 Publication Pattern Analysis :- </br>
#   - Analyzing temporal distribution of news articles across days, hours, and weekdays

# %%
data_analysis.analyze_publication_patterns()
# Out:
# Analyzing Publication Patterns...
# Publication Pattern Statistics:
# Average daily publications: 353.0
# Peak publishing hour: 0:00
# Most active day: Thursday
# Least active day: Saturday

# %% [markdown]
# 📈 Publication Pattern Analysis Insights:
# 1. 📅 Daily Publication Trends:
#
#    - Average of 353.0 articles published per day
#    - Shows consistent baseline coverage with occasional spikes
#    - Daily volume has increased significantly since 2010
#    - Notable volume peaks reaching over 2000 articles per day
# 2. ⏰ Hourly Distribution:
#
#    - Peak publishing activity at midnight (0:00)
#    - High concentration of articles in early hours
#    - Sharp drop-off in publishing after peak hours
#    - Limited activity during market trading hours
# 3. 📊 Weekly Patterns:
#
#    - Thursday confirmed as most active publishing day
#    - Saturday has lowest publication volume
#    - Clear weekday dominance in publishing schedule
#    - Weekend publishing significantly reduced
# 4. 💡 Key Implications:
#
#    - Publication timing focused on overnight/early morning
#    - Strong weekly cyclical pattern evident
#    - Volume growth indicates increasing news coverage
#    - Institutional scheduling drives timing patterns
# 5. 📱 Strategic Considerations:
#
#    - Best time to monitor news: Early morning hours
#    - Plan for heavy Thursday news volume
#    - Account for limited weekend coverage
#    - Trading strategies should consider overnight news flow

# %% [markdown]
# 📰 Publisher Analysis </br>
# Analyzing distribution and patterns of news publishers and their content

# %%
data_analysis.analyze_publishers()
# Out:
# Analyzing Publisher Patterns...
#
# Top 10 Publishers by Article Count:
# publisher
# Paul Quintaro        227495
# Lisa Levin           186716
# Benzinga Newsdesk    154645
# Charles Gross         96558
# Monica Gerson         82056
# Eddie Staley          56896
# Hal Lindon            48958
# Etf Professor         28251
# Juan Lopez            28110
# Benzinga Staff        27526
# Name: count, dtype: int64
# Publisher Statistics:
# Total unique publishers: 1031
# Total unique domains: 1021
#
# Top publishing domain: Paul Quintaro (227495 articles)
#
# Content Analysis for Top 5 Publishers:
#
# Paul Quintaro:
# Total articles: 227495
# Average headline length: 84.4 characters
#
# Lisa Levin:
# Total articles: 186716
# Average headline length: 47.5 characters
#
# Benzinga Newsdesk:
# Total articles: 154645
# Average headline length: 117.5 characters
#
# Charles Gross:
# Total articles: 96558
# Average headline length: 81.0 characters
#
# Monica Gerson:
# Total articles: 82056
# ...

# %% [markdown]
# 📰 Publisher Analysis Insights:
# 1. 📊 Publisher Landscape:
#
#    - 1,033 unique publishers contributing content
#    - 1,023 distinct publishing domains
#    - Highly concentrated among top publishers
#    - Wide range of publishing volumes across sources
# 2. 🏆 Top Publisher Profiles:
#
#    - Paul Quintaro: Dominant contributor (227,495 articles)
#    - Lisa Levin: Second most prolific (186,716 articles)
#    - Benzinga Newsdesk: Major institutional source (150,392 articles)
#    - Charles Gross: Significant volume (96,558 articles)
#    - Monica Gerson: Consistent contributor (82,056 articles)
# 3. 📝 Content Style Analysis:
#
#    - Benzinga Newsdesk: Longest headlines (114.7 chars)
#    - Paul Quintaro: Moderate length (84.4 chars)
#    - Charles Gross: Similar to Quintaro (81.0 chars)
#    - Monica Gerson: Concise style (51.0 chars)
#    - Lisa Levin: Most concise headlines (47.5 chars)
# 4. 💡 Key Observations:
#
#    - High concentration among top publishers
#    - Distinct writing styles evident in headline lengths
#    - Mix of individual and institutional contributors
#    - Significant volume disparity between top and lower tiers
# 5. 📈 Strategic Implications:
#
#    - Focus on top publishers for broad coverage
#    - Consider headline style when parsing content
#    - Monitor institutional vs individual sources
#    - Account for publisher-specific patterns

# %% [markdown]
# 💾 Saving Processed Data:</br>
# Exporting analyzed data to CSV for further use

# %%
data_analysis.save_to_csv()
# Out:
# Data saved to ../data/processed_financial_news.csv
